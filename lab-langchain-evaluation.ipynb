# %% [markdown]
# # Lab | Langchain Evaluation
#
# ## Intro
#
# Pick different sets of data and re-run this notebook. The point is for you to understand all steps involve and the many different ways one can and should evaluate LLM applications.
#
# What did you learn? - Let's discuss that in class

# %% [markdown]
# ## LangChain: Evaluation
#
# ### Outline:
#
# * Example generation
# * Manual evaluation (and debuging)
# * LLM-assisted evaluation

# %%
from dotenv import load_dotenv, find_dotenv
import os
_ = load_dotenv(find_dotenv())

OPENAI_API_KEY  = os.getenv('OPENAI_API_KEY')

# %% [markdown]
# ### Example 1

# %% [markdown]
# #### Create our QandA application

# %%
pip install "langchain==0.2.17" "langchain-community==0.2.19" "langchain-openai==0.1.25" "langchain-huggingface==0.0.3" faiss-cpu pypdf tiktoken python-dotenv
# Out:
# Collecting langchain==0.2.17
#   Downloading langchain-0.2.17-py3-none-any.whl.metadata (7.1 kB)
# Collecting langchain-community==0.2.19
#   Downloading langchain_community-0.2.19-py3-none-any.whl.metadata (2.7 kB)
# Collecting langchain-openai==0.1.25
#   Downloading langchain_openai-0.1.25-py3-none-any.whl.metadata (2.6 kB)
# Collecting langchain-huggingface==0.0.3
#   Downloading langchain_huggingface-0.0.3-py3-none-any.whl.metadata (1.2 kB)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.14.3-cp310-abi3-macosx_14_0_arm64.whl.metadata (7.8 kB)
# Collecting pypdf
#   Downloading pypdf-6.13.3-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: tiktoken in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (0.13.0)
# Requirement already satisfied: python-dotenv in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (1.2.2)
# Requirement already satisfied: PyYAML>=5.3 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from langchain==0.2.17) (6.0.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from langchain==0.2.17) (2.0.49)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from langchain==0.2.17) (3.13.5)
# Collecting langchain-core<0.3.0,>=0.2.43 (from langchain==0.2.17)
#   Downloading langchain_core-0.2.43-py3-none-any.whl.metadata (6.2 kB)
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain==0.2.17)
#   Downloading langchain_text_splitters-0.2.4-py3-none-any.whl.metadata (2.3 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain==0.2.17)
#   Using cached langsmith-0.1.147-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy<2,>=1 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from langchain==0.2.17) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from langchain==0.2.17) (2.13.4)
# Requirement already satisfied: requests<3,>=2 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from langchain==0.2.17) (2.34.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from langchain==0.2.17) (8.5.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from langchain-community==0.2.19) (0.6.7)
# Collecting openai<2.0.0,>=1.40.0 (from langchain-openai==0.1.25)
#   Using cached openai-1.109.1-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from langchain-huggingface==0.0.3) (0.36.2)
# Requirement already satisfied: sentence-transformers>=2.6.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from langchain-huggingface==0.0.3) (5.5.1)
# Requirement already satisfied: tokenizers>=0.19.1 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from langchain-huggingface==0.0.3) (0.19.1)
# Requirement already satisfied: transformers>=4.39.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from langchain-huggingface==0.0.3) (4.41.2)
# Requirement already satisfied: regex in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from tiktoken) (2026.5.9)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.17) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.17) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.17) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.17) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.17) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.17) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.17) (1.24.2)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.19) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.19) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from langchain-core<0.3.0,>=0.2.43->langchain==0.2.17) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from langchain-core<0.3.0,>=0.2.43->langchain==0.2.17) (23.2)
# Requirement already satisfied: typing-extensions>=4.7 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from langchain-core<0.3.0,>=0.2.43->langchain==0.2.17) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.43->langchain==0.2.17) (3.1.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.2.17) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.2.17) (3.11.9)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.2.17) (1.0.0)
# Requirement already satisfied: anyio in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.2.17) (4.13.0)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.2.17) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.2.17) (1.0.9)
# Requirement already satisfied: idna in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.2.17) (3.15)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.2.17) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.1.25) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.1.25) (0.15.0)
# Requirement already satisfied: sniffio in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.1.25) (1.3.1)
# Requirement already satisfied: tqdm>4 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.1.25) (4.67.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from pydantic<3,>=1->langchain==0.2.17) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from pydantic<3,>=1->langchain==0.2.17) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from pydantic<3,>=1->langchain==0.2.17) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from requests<3,>=2->langchain==0.2.17) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from requests<3,>=2->langchain==0.2.17) (2.7.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.19) (1.1.0)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface==0.0.3) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface==0.0.3) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface==0.0.3) (1.5.0)
# Requirement already satisfied: torch>=1.11.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (2.12.0)
# Requirement already satisfied: scikit-learn>=0.22.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (1.8.0)
# Requirement already satisfied: scipy>=1.0.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (1.17.1)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from transformers>=4.39.0->langchain-huggingface==0.0.3) (0.7.0)
# Requirement already satisfied: joblib>=1.3.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from scikit-learn>=0.22.0->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from scikit-learn>=0.22.0->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (3.6.0)
# Requirement already satisfied: setuptools<82 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (3.6.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (3.0.3)
# Downloading langchain-0.2.17-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 1.4 MB/s  0:00:010m eta 0:00:01
# Downloading langchain_community-0.2.19-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 5.4 MB/s  0:00:00 eta 0:00:01
# Downloading langchain_openai-0.1.25-py3-none-any.whl (51 kB)
# Downloading langchain_huggingface-0.0.3-py3-none-any.whl (17 kB)
# Downloading langchain_core-0.2.43-py3-none-any.whl (397 kB)
# Downloading langchain_text_splitters-0.2.4-py3-none-any.whl (25 kB)
# Using cached langsmith-0.1.147-py3-none-any.whl (311 kB)
# Using cached openai-1.109.1-py3-none-any.whl (948 kB)
# Downloading faiss_cpu-1.14.3-cp310-abi3-macosx_14_0_arm64.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 4.5 MB/s  0:00:01m eta 0:00:01
# Downloading pypdf-6.13.3-py3-none-any.whl (347 kB)
# Installing collected packages: pypdf, faiss-cpu, openai, langsmith, langchain-core, langchain-text-splitters, langchain-openai, langchain-huggingface, langchain, langchain-community
#   Attempting uninstall: openaim━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/10 [faiss-cpu]
#     Found existing installation: openai 2.43.0━━━━━━━━━━━━━━━━  1/10 [faiss-cpu]
#     Uninstalling openai-2.43.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/10 [openai]
#       Successfully uninstalled openai-2.43.0━━━━━━━━━━━━━━━━━━  2/10 [openai]
#   Attempting uninstall: langsmith0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/10 [openai]
#     Found existing installation: langsmith 0.8.16━━━━━━━━━━━━━  2/10 [openai]
#     Uninstalling langsmith-0.8.16:━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/10 [openai]
#       Successfully uninstalled langsmith-0.8.16━━━━━━━━━━━━━━━  2/10 [openai]
#   Attempting uninstall: langchain-corem━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/10 [langsmith]
#     Found existing installation: langchain-core 1.4.7━━━━━━━━━  3/10 [langsmith]
#     Uninstalling langchain-core-1.4.7:━━━━━━━━━━━━━━━━━━━━━━━━  3/10 [langsmith]
#       Successfully uninstalled langchain-core-1.4.7━━━━━━━━━━━  3/10 [langsmith]
#   Attempting uninstall: langchain-text-splitters━━━━━━━━━━━━━━━━━━  4/10 [langchain-core]
#     Found existing installation: langchain-text-splitters 0.0.2  4/10 [langchain-core]
#     Uninstalling langchain-text-splitters-0.0.2:━━━━━━━━━━━━━━  4/10 [langchain-core]
#       Successfully uninstalled langchain-text-splitters-0.0.2━  4/10 [langchain-core]
#   Attempting uninstall: langchain-openai━━━━━━━━━━━━━━━━━━━━━━  4/10 [langchain-core]
#     Found existing installation: langchain-openai 1.3.2━━━━━━━  4/10 [langchain-core]
#     Uninstalling langchain-openai-1.3.2:━━━━━━━━━━━━━━━━━━━━━━  4/10 [langchain-core]
#       Successfully uninstalled langchain-openai-1.3.2━━━━━━━━━  4/10 [langchain-core]
#   Attempting uninstall: langchainm━━━━━━━━━━━━━━━━━━━━━━━  4/10 [langchain-core]
#     Found existing installation: langchain 1.3.9━━━━━━━━━━━━━━  4/10 [langchain-core]
#     Uninstalling langchain-1.3.9:m━━━━━━━━━━━━━━━━━━━━━━━  4/10 [langchain-core]
#       Successfully uninstalled langchain-1.3.9━━━━━━━━━━━━━━━━  4/10 [langchain-core]
#   Attempting uninstall: langchain-communitym╺━━━━━━━  8/10 [langchain]]
#     Found existing installation: langchain-community 0.0.38━━━  8/10 [langchain]
#     Uninstalling langchain-community-0.0.38:╺━━━  9/10 [langchain-community]
#       Successfully uninstalled langchain-community-0.0.380m━━━  9/10 [langchain-community]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 [langchain-community]ngchain-community]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langserve 0.3.3 requires langchain-core<2,>=0.3, but you have langchain-core 0.2.43 which is incompatible.
# langgraph-prebuilt 1.1.0 requires langchain-core>=1.3.1, but you have langchain-core 0.2.43 which is incompatible.
# langchain-classic 1.0.7 requires langchain-core<2.0.0,>=1.3.3, but you have langchain-core 0.2.43 which is incompatible.
# langchain-classic 1.0.7 requires langchain-text-splitters<2.0.0,>=1.1.2, but you have langchain-text-splitters 0.2.4 which is incompatible.
# langchain-pinecone 0.2.13 requires langchain-core<2.0.0,>=0.3.34, but you have langchain-core 0.2.43 which is incompatible.
# langchain-pinecone 0.2.13 requires langchain-openai>=0.3.11, but you have langchain-openai 0.1.25 which is incompatible.
# langgraph-sdk 0.4.2 requires langchain-core<2,>=1.4.0, but you have langchain-core 0.2.43 which is incompatible.
# langgraph 1.2.5 requires langchain-core<2,>=1.4.7, but you have langchain-core 0.2.43 which is incompatible.
# Successfully installed faiss-cpu-1.14.3 langchain-0.2.17 langchain-community-0.2.19 langchain-core-0.2.43 langchain-huggingface-0.0.3 langchain-openai-0.1.25 langchain-text-splitters-0.2.4 langsmith-0.1.147 openai-1.109.1 pypdf-6.13.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain.chains import RetrievalQA
from langchain_openai import ChatOpenAI
from langchain.llms import OpenAI
from langchain_huggingface import HuggingFaceEmbeddings
from langchain.document_loaders import CSVLoader, TextLoader
from langchain.indexes import VectorstoreIndexCreator
from langchain.vectorstores import DocArrayInMemorySearch
from langchain.chains import LLMChain

# %%
file = './data/OutdoorClothingCatalog_1000.csv'
loader = CSVLoader(file_path=file)
data = loader.load()

# %%
# !pip install --upgrade --force-reinstall sentence-transformers

# %%
pip install docarray
# Out:
# Collecting docarray
#   Downloading docarray-0.41.0-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: numpy>=1.17.3 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from docarray) (1.26.4)
# Requirement already satisfied: orjson>=3.8.2 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from docarray) (3.11.9)
# Requirement already satisfied: pydantic>=1.10.8 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from docarray) (2.13.4)
# Requirement already satisfied: rich>=13.1.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from docarray) (15.0.0)
# Collecting types-requests>=2.28.11.6 (from docarray)
#   Downloading types_requests-2.33.0.20260518-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from docarray) (0.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from pydantic>=1.10.8->docarray) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from pydantic>=1.10.8->docarray) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from pydantic>=1.10.8->docarray) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from pydantic>=1.10.8->docarray) (0.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from rich>=13.1.0->docarray) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from rich>=13.1.0->docarray) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=13.1.0->docarray) (0.1.2)
# Requirement already satisfied: urllib3>=2 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from types-requests>=2.28.11.6->docarray) (2.7.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from typing-inspect>=0.8.0->docarray) (1.1.0)
# Downloading docarray-0.41.0-py3-none-any.whl (302 kB)
# Downloading types_requests-2.33.0.20260518-py3-none-any.whl (21 kB)
# Installing collected packages: types-requests, docarray
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [docarray]1/2 [docarray]
# Successfully installed docarray-0.41.0 types-requests-2.33.0.20260518
# Note: you may need to restart the kernel to use updated packages.

# %%
index = VectorstoreIndexCreator(
    vectorstore_cls=DocArrayInMemorySearch,
    embedding=HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2", model_kwargs = {'device': 'cpu'})
).from_loaders([loader])
# Out:
# /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
llm = ChatOpenAI(temperature = 0.0)
qa = RetrievalQA.from_chain_type(
    llm=llm, 
    chain_type="stuff", 
    retriever=index.vectorstore.as_retriever(), 
    verbose=True,
    chain_type_kwargs = {
        "document_separator": "<<<<>>>>>"
    }
)

# %% [markdown]
# #### Coming up with test datapoints

# %%
data[10]
# Out:
# Document(metadata={'source': './data/OutdoorClothingCatalog_1000.csv', 'row': 10}, page_content=": 10\nname: Cozy Comfort Pullover Set, Stripe\ndescription: Perfect for lounging, this striped knit set lives up to its name. We used ultrasoft fabric and an easy design that's as comfortable at bedtime as it is when we have to make a quick run out.\n\nSize & Fit\n- Pants are Favorite Fit: Sits lower on the waist.\n- Relaxed Fit: Our most generous fit sits farthest from the body.\n\nFabric & Care\n- In the softest blend of 63% polyester, 35% rayon and 2% spandex.\n\nAdditional Features\n- Relaxed fit top with raglan sleeves and rounded hem.\n- Pull-on pants have a wide elastic waistband and drawstring, side pockets and a modern slim leg.\n\nImported.")

# %%
data[11]
# Out:
# Document(metadata={'source': './data/OutdoorClothingCatalog_1000.csv', 'row': 11}, page_content=': 11\nname: Ultra-Lofty 850 Stretch Down Hooded Jacket\ndescription: This technical stretch down jacket from our DownTek collection is sure to keep you warm and comfortable with its full-stretch construction providing exceptional range of motion. With a slightly fitted style that falls at the hip and best with a midweight layer, this jacket is suitable for light activity up to 20° and moderate activity up to -30°. The soft and durable 100% polyester shell offers complete windproof protection and is insulated with warm, lofty goose down. Other features include welded baffles for a no-stitch construction and excellent stretch, an adjustable hood, an interior media port and mesh stash pocket and a hem drawcord. Machine wash and dry. Imported.')

# %% [markdown]
# #### Hard-coded examples

# %%
from langchain.prompts import PromptTemplate

# %%
from langchain.prompts import PromptTemplate
from langchain.schema import BaseOutputParser
from pydantic import BaseModel, Field

examples = [
    {
        "query": "Do the Cozy Comfort Pullover Set\
        have side pockets?",
        "answer": "Yes"
    },
    {
        "query": "What collection is the Ultra-Lofty \
        850 Stretch Down Hooded Jacket from?",
        "answer": "The DownTek collection"
    }
]

# Define the prompt template
prompt_template = PromptTemplate(
    input_variables=["query"],
    template="Examples:\n"
             "1. Query: Do the Cozy Comfort Pullover Set have side pockets?\n"
             "   Answer: Yes\n"
             "2. Query: What collection is the Ultra-Lofty 850 Stretch Down Hooded Jacket from?\n"
             "   Answer: The DownTek collection\n"
             "Query: {query}\n"
             "Answer:"
)

# Define the output model
class Answer(BaseModel):
    answer: str = Field(description="The answer to the query")

# Create the output parser
class AnswerOutputParser(BaseOutputParser):
    def parse(self, text: str) -> Answer:
        # Split the response to get the answer
        answer = text.strip().split("Answer:")[-1].strip()
        return Answer(answer=answer)

# Initialize the LLM
# llm = OpenAI()
llm = ChatOpenAI()

# Create the LLMChain
llm_chain = LLMChain(
    llm=llm,
    prompt=prompt_template,
    output_parser=AnswerOutputParser()
)

# Example query
query = "Is the Cozy Comfort Pullover Set available in different colors?"

# Run the chain
result = llm_chain.run({"query": query})

# Print the result
print(result)
# Out:
# answer='Yes, it is available in multiple colors such as black, gray, and navy.'

# %% [markdown]
# #### LLM-Generated examples

# %%
from langchain.evaluation.qa import QAGenerateChain

# %%
example_gen_chain = QAGenerateChain.from_llm(ChatOpenAI())

# %%
llm_chain = LLMChain(llm=llm, prompt=prompt_template)

# %%
new_examples = example_gen_chain.apply_and_parse(
    [{"doc": t} for t in data[:5]]
)
# Out:
# /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages/langchain/chains/llm.py:366: UserWarning: The apply_and_parse method is deprecated, instead pass an output parser directly to LLMChain.
#   warnings.warn(

# %%
new_examples[0]
# Out:
# {'qa_pairs': {'query': "What is the approximate weight of the Women's Campside Oxfords per pair?",
#   'answer': "The approximate weight of the Women's Campside Oxfords per pair is 1 lb. 1 oz."}}

# %%
data[0]
# Out:
# Document(metadata={'source': './data/OutdoorClothingCatalog_1000.csv', 'row': 0}, page_content=": 0\nname: Women's Campside Oxfords\ndescription: This ultracomfortable lace-to-toe Oxford boasts a super-soft canvas, thick cushioning, and quality construction for a broken-in feel from the first time you put them on. \n\nSize & Fit: Order regular shoe size. For half sizes not offered, order up to next whole size. \n\nSpecs: Approx. weight: 1 lb.1 oz. per pair. \n\nConstruction: Soft canvas material for a broken-in feel and look. Comfortable EVA innersole with Cleansport NXT® antimicrobial odor control. Vintage hunt, fish and camping motif on innersole. Moderate arch contour of innersole. EVA foam midsole for cushioning and support. Chain-tread-inspired molded rubber outsole with modified chain-tread pattern. Imported. \n\nQuestions? Please contact us for any inquiries.")

# %%
d_flattened = [data['qa_pairs'] for data in new_examples]
d_flattened
# Out:
# [{'query': "What is the approximate weight of the Women's Campside Oxfords per pair?",
#   'answer': "The approximate weight of the Women's Campside Oxfords per pair is 1 lb. 1 oz."},
#  {'query': 'What are the dimensions of the small and medium sizes of the Recycled Waterhog Dog Mat, Chevron Weave?',
#   'answer': 'The small size has dimensions of 18" x 28" and the medium size has dimensions of 22.5" x 34.5".'},
#  {'query': "What are some key features of the Infant and Toddler Girls' Coastal Chill Swimsuit, Two-Piece according to the document?",
#   'answer': "Some key features of the Infant and Toddler Girls' Coastal Chill Swimsuit, Two-Piece include bright colors, ruffles, exclusive whimsical prints, four-way-stretch and chlorine-resistant fabric, UPF 50+ rated fabric for sun protection, crossover no-slip straps, fully lined bottom for secure fit and maximum coverage, and the recommendation to machine wash and line dry for best results."},
#  {'query': 'What is the composition of the body and lining of the Refresh Swimwear, V-Neck Tankini Contrasts?',
#   'answer': 'The body of the tankini is made of 82% recycled nylon and 18% Lycra® spandex, while the lining is made of 90% recycled nylon and 10% Lycra® spandex.'},
#  {'query': 'What technology is used in the EcoFlex 3L Storm Pants to make them more breathable?',
#   'answer': 'The EcoFlex 3L Storm Pants utilize the state-of-the-art TEK O2 technology to offer the most breathability.'}]

# %% [markdown]
# #### Combine examples

# %%
# examples += new_example
examples += d_flattened

# %%
examples[0]
# Out:
# {'query': 'Do the Cozy Comfort Pullover Set        have side pockets?',
#  'answer': 'Yes'}

# %%
qa.invoke(examples[0]["query"])
# Out:
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# > Finished chain.
# {'query': 'Do the Cozy Comfort Pullover Set        have side pockets?',
#  'result': 'Yes, the Cozy Comfort Pullover Set does have side pockets.'}

# %% [markdown]
# ### Manual Evaluation - Fun part

# %%
import langchain
langchain.debug = True

# %%
qa.invoke(examples[0]["query"])
# Out:
# [chain/start] [chain:RetrievalQA] Entering Chain run with input:
# {
#   "query": "Do the Cozy Comfort Pullover Set        have side pockets?"
# }
# [chain/start] [chain:RetrievalQA > chain:StuffDocumentsChain] Entering Chain run with input:
# [inputs]
# [chain/start] [chain:RetrievalQA > chain:StuffDocumentsChain > chain:LLMChain] Entering Chain run with input:
# {
#   "question": "Do the Cozy Comfort Pullover Set        have side pockets?",
#   "context": ": 73\nname: Cozy Cuddles Knit Pullover Set\ndescription: Perfect for lounging, this knit set lives up to its name. We used ultrasoft fabric and an easy design that's as comfortable at bedtime as it is when we have to make a quick run out. \n\nSize & Fit \nPants are Favorite Fit: Sits lower on the waist. \nRelaxed Fit: Our most generous fit sits farthest from the body. \n\nFabric & Care \nIn the softest blend of 63% polyester, 35% rayon and 2% spandex.\n\nAdditional Features \nRelaxed fit top with raglan sleeves and rounded hem. \nPull-on pants have a wide elastic waistband and drawstring, side pockets and a modern slim leg. \nImported.<<<<>>>>>Berber fleece-lined pockets keep hands warm. One pocket has a hidden security pocket tucked inside. Imported.<<<<>>>>>: 10\nname: Cozy Comfort Pullover Set, Stripe\ndescription: Perfect for lounging, this striped knit set lives up to its name. We used ultrasoft fabric and an easy design that's as comfortable at bedtime as it is when we have to make a quick run out.\n\nSize & Fit\n- Pants are Favorite Fit: Sits lower on the waist.\n- Relaxed Fit: Our most generous fit sits farthest from the body.\n\nFabric & Care\n- In the softest blend of 63% polyester, 35% rayon and 2% spandex.\n\nAdditional Features\n- Relaxed fit top with raglan sleeves and rounded hem.\n- Pull-on pants have a wide elastic waistband and drawstring, side pockets and a modern slim leg.\n\nImported.<<<<>>>>>Additional Features: Bonded construction insulates for extra warmth and won't stretch out of shape. Classic shirt jac styling, with collar and modified hem for extra coverage. Full snap placket for easy on/off. Chest pockets with snap closures. Pencil pocket on chest. Underarm gussets enhance mobility. Berber fleece-lined pockets keep hands warm. One pocket has a hidden security pocket tucked inside. Imported"
# }
# [llm/start] [chain:RetrievalQA > chain:StuffDocumentsChain > chain:LLMChain > llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "System: Use the following pieces of context to answer the user's question. \nIf you don't know the answer, just say that you don't know, don't try to make up an answer.\n----------------\n: 73\nname: Cozy Cuddles Knit Pullover Set\ndescription: Perfect for lounging, this knit set lives up to its name. We used ultrasoft fabric and an easy design that's as comfortable at bedtime as it is when we have to make a quick run out. \n\nSize & Fit \nPants are Favorite Fit: Sits lower on the waist. \nRelaxed Fit: Our most generous fit sits farthest from the body. \n\nFabric & Care \nIn the softest blend of 63% polyester, 35% rayon and 2% spandex.\n\nAdditional Features \nRelaxed fit top with raglan sleeves and rounded hem. \nPull-on pants have a wide elastic waistband and drawstring, side pockets and a modern slim leg. \nImported.<<<<>>>>>Berber fleece-lined pockets keep hands warm. One pocket has a hidden security pocket tucked inside. Imported.<<<<>>>>>: 10\nname: Cozy Comfort Pullover Set, Stripe\ndescription: Perfect for lounging, this striped knit set lives up to its name. We used ultrasoft fabric and an easy design that's as comfortable at bedtime as it is when we have to make a quick run out.\n\nSize & Fit\n- Pants are Favorite Fit: Sits lower on the waist.\n- Relaxed Fit: Our most generous fit sits farthest from the body.\n\nFabric & Care\n- In the softest blend of 63% polyester, 35% rayon and 2% spandex.\n\nAdditional Features\n- Relaxed fit top with raglan sleeves and rounded hem.\n- Pull-on pants have a wide elastic waistband and drawstring, side pockets and a modern slim leg.\n\nImported.<<<<>>>>>Additional Features: Bonded construction insulates for extra warmth and won't stretch out of shape. Classic shirt jac styling, with collar and modified hem for extra coverage. Full snap placket for easy on/off. Chest pockets with snap closures. Pencil pocket on chest. Underarm gussets enhance mobility. Berber fleece-lined pockets keep hands warm. One pocket has a hidden security pocket tucked inside. Imported\nHuman: Do the Cozy Comfort Pullover Set        have side pockets?"
#   ]
# }
# [llm/end] [chain:RetrievalQA > chain:StuffDocumentsChain > chain:LLMChain > llm:ChatOpenAI] [2.06s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "Yes, the Cozy Comfort Pullover Set does have side pockets.",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "Yes, the Cozy Comfort Pullover Set does have side pockets.",
#             "additional_kwargs": {
#               "refusal": null
#             },
#             "response_metadata": {
#               "token_usage": {
#                 "completion_tokens": 14,
#                 "prompt_tokens": 504,
#                 "total_tokens": 518,
#                 "completion_tokens_details": {
#                   "accepted_prediction_tokens": 0,
#                   "audio_tokens": 0,
#                   "reasoning_tokens": 0,
#                   "rejected_prediction_tokens": 0
#                 },
#                 "prompt_tokens_details": {
#                   "audio_tokens": 0,
#                   "cached_tokens": 0
#                 }
#               },
#               "model_name": "gpt-3.5-turbo-0125",
#               "system_fingerprint": null,
#               "finish_reason": "stop",
#               "logprobs": null
#             },
#             "type": "ai",
#             "id": "run-5dbc3563-e0fe-4a13-867a-63763adb84a5-0",
#             "usage_metadata": {
#               "input_tokens": 504,
#               "output_tokens": 14,
#               "total_tokens": 518
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 14,
#       "prompt_tokens": 504,
#       "total_tokens": 518,
#       "completion_tokens_details": {
#         "accepted_prediction_tokens": 0,
#         "audio_tokens": 0,
#         "reasoning_tokens": 0,
#         "rejected_prediction_tokens": 0
#       },
#       "prompt_tokens_details": {
#         "audio_tokens": 0,
#         "cached_tokens": 0
#       }
#     },
#     "model_name": "gpt-3.5-turbo-0125",
#     "system_fingerprint": null
#   },
#   "run": null
# }
# [chain/end] [chain:RetrievalQA > chain:StuffDocumentsChain > chain:LLMChain] [2.07s] Exiting Chain run with output:
# {
#   "text": "Yes, the Cozy Comfort Pullover Set does have side pockets."
# }
# [chain/end] [chain:RetrievalQA > chain:StuffDocumentsChain] [2.07s] Exiting Chain run with output:
# {
#   "output_text": "Yes, the Cozy Comfort Pullover Set does have side pockets."
# }
# [chain/end] [chain:RetrievalQA] [2.10s] Exiting Chain run with output:
# {
#   "result": "Yes, the Cozy Comfort Pullover Set does have side pockets."
# }
# {'query': 'Do the Cozy Comfort Pullover Set        have side pockets?',
#  'result': 'Yes, the Cozy Comfort Pullover Set does have side pockets.'}

# %%
# Turn off the debug mode
langchain.debug = False

# %% [markdown]
# ### LLM assisted evaluation

# %%
examples += d_flattened

# %%
examples
# Out:
# [{'query': 'Do the Cozy Comfort Pullover Set        have side pockets?',
#   'answer': 'Yes'},
#  {'query': 'What collection is the Ultra-Lofty         850 Stretch Down Hooded Jacket from?',
#   'answer': 'The DownTek collection'},
#  {'query': "What is the approximate weight of the Women's Campside Oxfords per pair?",
#   'answer': "The approximate weight of the Women's Campside Oxfords per pair is 1 lb. 1 oz."},
#  {'query': 'What are the dimensions of the small and medium sizes of the Recycled Waterhog Dog Mat, Chevron Weave?',
#   'answer': 'The small size has dimensions of 18" x 28" and the medium size has dimensions of 22.5" x 34.5".'},
#  {'query': "What are some key features of the Infant and Toddler Girls' Coastal Chill Swimsuit, Two-Piece according to the document?",
#   'answer': "Some key features of the Infant and Toddler Girls' Coastal Chill Swimsuit, Two-Piece include bright colors, ruffles, exclusive whimsical prints, four-way-stretch and chlorine-resistant fabric, UPF 50+ rated fabric for sun protection, crossover no-slip straps, fully lined bottom for secure fit and maximum coverage, and the recommendation to machine wash and line dry for best results."},
#  {'query': 'What is the composition of the body and lining of the Refresh Swimwear, V-Neck Tankini Contrasts?',
#   'answer': 'The body of the tankini is made of 82% recycled nylon and 18% Lycra® spandex, while the lining is made of 90% recycled nylon and 10% Lycra® spandex.'},
#  {'query': 'What technology is used in the EcoFlex 3L Storm Pants to make them more breathable?',
#   'answer': 'The EcoFlex 3L Storm Pants utilize the state-of-the-art TEK O2 technology to offer the most breathability.'},
#  {'query': "What is the approximate weight of the Women's Campside Oxfords per pair?",
#   'answer': "The approximate weight of the Women's Campside Oxfords per pair is 1 lb. 1 oz."},
#  {'query': 'What are the dimensions of the small and medium sizes of the Recycled Waterhog Dog Mat, Chevron Weave?',
#   'answer': 'The small size has dimensions of 18" x 28" and the medium size has dimensions of 22.5" x 34.5".'},
#  {'query': "What are some key features of the Infant and Toddler Girls' Coastal Chill Swimsuit, Two-Piece according to the document?",
#   'answer': "Some key features of the Infant and Toddler Girls' Coastal Chill Swimsuit, Two-Piece include bright colors, ruffles, exclusive whimsical prints, four-way-stretch and chlorine-resistant fabric, UPF 50+ rated fabric for sun protection, crossover no-slip straps, fully lined bottom for secure fit and maximum coverage, and the recommendation to machine wash and line dry for best results."},
#  {'query': 'What is the composition of the body and lining of the Refresh Swimwear, V-Neck Tankini Contrasts?',
#   'answer': 'The body of the tankini is made of 82% recycled nylon and 18% Lycra® spandex, while the lining is made of 90% recycled nylon and 10% Lycra® spandex.'},
#  {'query': 'What technology is used in the EcoFlex 3L Storm Pants to make them more breathable?',
#   'answer': 'The EcoFlex 3L Storm Pants utilize the state-of-the-art TEK O2 technology to offer the most breathability.'}]

# %%
predictions = qa.batch(examples)
# Out:
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# > Finished chain.
#
# > Finished chain.
#
# > Finished chain.
#
# > Finished chain.
#
# > Finished chain.
#
# > Finished chain.
#
# > Finished chain.
#
# > Finished chain.
#
# > Finished chain.
#
# > Finished chain.
#
# > Finished chain.
#
# > Finished chain.

# %%
predictions
# Out:
# [{'query': 'Do the Cozy Comfort Pullover Set        have side pockets?',
#   'answer': 'Yes',
#   'result': 'Yes, the Cozy Comfort Pullover Set has side pockets.'},
#  {'query': 'What collection is the Ultra-Lofty         850 Stretch Down Hooded Jacket from?',
#   'answer': 'The DownTek collection',
#   'result': 'The Ultra-Lofty 850 Stretch Down Hooded Jacket is from the DownTek collection.'},
#  {'query': "What is the approximate weight of the Women's Campside Oxfords per pair?",
#   'answer': "The approximate weight of the Women's Campside Oxfords per pair is 1 lb. 1 oz.",
#   'result': "The approximate weight of the Women's Campside Oxfords per pair is 1 lb. 1 oz."},
#  {'query': 'What are the dimensions of the small and medium sizes of the Recycled Waterhog Dog Mat, Chevron Weave?',
#   'answer': 'The small size has dimensions of 18" x 28" and the medium size has dimensions of 22.5" x 34.5".',
#   'result': 'The dimensions of the small size of the Recycled Waterhog Dog Mat, Chevron Weave are 18" x 28", and the dimensions of the medium size are 22.5" x 34.5".'},
#  {'query': "What are some key features of the Infant and Toddler Girls' Coastal Chill Swimsuit, Two-Piece according to the document?",
#   'answer': "Some key features of the Infant and Toddler Girls' Coastal Chill Swimsuit, Two-Piece include bright colors, ruffles, exclusive whimsical prints, four-way-stretch and chlorine-resistant fabric, UPF 50+ rated fabric for sun protection, crossover no-slip straps, fully lined bottom for secure fit and maximum coverage, and the recommendation to machine wash and line dry for best results.",
#   'result': "Some key features of the Infant and Toddler Girls' Coastal Chill Swimsuit, Two-Piece are:\n- Bright colors, ruffles, and exclusive whimsical prints\n- Four-way-stretch and chlorine-resistant fabric\n- UPF 50+ rated fabric for high sun protection\n- Crossover no-slip straps and fully lined bottom for a secure fit and coverage\n- Machine washable and best results with line drying"},
#  {'query': 'What is the composition of the body and lining of the Refresh Swimwear, V-Neck Tankini Contrasts?',
#   'answer': 'The body of the tankini is made of 82% recycled nylon and 18% Lycra® spandex, while the lining is made of 90% recycled nylon and 10% Lycra® spandex.',
#   'result': 'The body of the Refresh Swimwear, V-Neck Tankini Contrasts is made of 82% recycled nylon with 18% Lycra® spandex, while the lining is made of 90% recycled nylon with 10% Lycra® spandex.'},
#  {'query': 'What technology is used in the EcoFlex 3L Storm Pants to make them more breathable?',
#   'answer': 'The EcoFlex 3L Storm Pants utilize the state-of-the-art TEK O2 technology to offer the most breathability.',
#   'result': 'The EcoFlex 3L Storm Pants use TEK O2 technology to make them more breathable.'},
#  {'query': "What is the approximate weight of the Women's Campside Oxfords per pair?",
#   'answer': "The approximate weight of the Women's Campside Oxfords per pair is 1 lb. 1 oz.",
#   'result': "The approximate weight of the Women's Campside Oxfords per pair is 1 lb. 1 oz."},
#  {'query': 'What are the dimensions of the small and medium sizes of the Recycled Waterhog Dog Mat, Chevron Weave?',
#   'answer': 'The small size has dimensions of 18" x 28" and the medium size has dimensions of 22.5" x 34.5".',
#   'result': 'The dimensions of the small size of the Recycled Waterhog Dog Mat, Chevron Weave are 18" x 28", and the dimensions of the medium size are 22.5" x 34.5".'},
#  {'query': "What are some key features of the Infant and Toddler Girls' Coastal Chill Swimsuit, Two-Piece according to the document?",
#   'answer': "Some key features of the Infant and Toddler Girls' Coastal Chill Swimsuit, Two-Piece include bright colors, ruffles, exclusive whimsical prints, four-way-stretch and chlorine-resistant fabric, UPF 50+ rated fabric for sun protection, crossover no-slip straps, fully lined bottom for secure fit and maximum coverage, and the recommendation to machine wash and line dry for best results.",
#   'result': "Some key features of the Infant and Toddler Girls' Coastal Chill Swimsuit, Two-Piece are:\n- Bright colors, ruffles, and exclusive whimsical prints\n- Four-way-stretch and chlorine-resistant fabric\n- UPF 50+ rated fabric for high sun protection\n- Crossover no-slip straps and fully lined bottom for a secure fit and coverage\n- Machine washable and line dry for best results"},
#  {'query': 'What is the composition of the body and lining of the Refresh Swimwear, V-Neck Tankini Contrasts?',
#   'answer': 'The body of the tankini is made of 82% recycled nylon and 18% Lycra® spandex, while the lining is made of 90% recycled nylon and 10% Lycra® spandex.',
#   'result': 'The body of the Refresh Swimwear, V-Neck Tankini Contrasts is made of 82% recycled nylon with 18% Lycra® spandex, while the lining is made of 90% recycled nylon with 10% Lycra® spandex.'},
#  {'query': 'What technology is used in the EcoFlex 3L Storm Pants to make them more breathable?',
#   'answer': 'The EcoFlex 3L Storm Pants utilize the state-of-the-art TEK O2 technology to offer the most breathability.',
#   'result': 'The EcoFlex 3L Storm Pants use TEK O2 technology to make them more breathable.'}]

# %%
from langchain.evaluation.qa import QAEvalChain

# %%
llm = ChatOpenAI(temperature=0)
eval_chain = QAEvalChain.from_llm(llm)

# %%
graded_outputs = eval_chain.evaluate(examples, predictions)

# %%
graded_outputs
# Out:
# [{'results': 'CORRECT'},
#  {'results': 'CORRECT'},
#  {'results': 'CORRECT'},
#  {'results': 'CORRECT'},
#  {'results': 'CORRECT'},
#  {'results': 'CORRECT'},
#  {'results': 'CORRECT'},
#  {'results': 'CORRECT'},
#  {'results': 'CORRECT'},
#  {'results': 'CORRECT'},
#  {'results': 'CORRECT'},
#  {'results': 'CORRECT'}]

# %%
for i, eg in enumerate(examples):
    print(f"Example {i}:")
    print("Question: " + predictions[i]['query'])
    print("Real Answer: " + predictions[i]['answer'])
    print("Predicted Answer: " + predictions[i]['result'])
    # print("Predicted Grade: " + graded_outputs[i]['text'])
    print()
# Out:
# Example 0:
# Question: Do the Cozy Comfort Pullover Set        have side pockets?
# Real Answer: Yes
# Predicted Answer: Yes, the Cozy Comfort Pullover Set has side pockets.
#
# Example 1:
# Question: What collection is the Ultra-Lofty         850 Stretch Down Hooded Jacket from?
# Real Answer: The DownTek collection
# Predicted Answer: The Ultra-Lofty 850 Stretch Down Hooded Jacket is from the DownTek collection.
#
# Example 2:
# Question: What is the approximate weight of the Women's Campside Oxfords per pair?
# Real Answer: The approximate weight of the Women's Campside Oxfords per pair is 1 lb. 1 oz.
# Predicted Answer: The approximate weight of the Women's Campside Oxfords per pair is 1 lb. 1 oz.
#
# Example 3:
# Question: What are the dimensions of the small and medium sizes of the Recycled Waterhog Dog Mat, Chevron Weave?
# Real Answer: The small size has dimensions of 18" x 28" and the medium size has dimensions of 22.5" x 34.5".
# Predicted Answer: The dimensions of the small size of the Recycled Waterhog Dog Mat, Chevron Weave are 18" x 28", and the dimensions of the medium size are 22.5" x 34.5".
#
# Example 4:
# Question: What are some key features of the Infant and Toddler Girls' Coastal Chill Swimsuit, Two-Piece according to the document?
# Real Answer: Some key features of the Infant and Toddler Girls' Coastal Chill Swimsuit, Two-Piece include bright colors, ruffles, exclusive whimsical prints, four-way-stretch and chlorine-resistant fabric, UPF 50+ rated fabric for sun protection, crossover no-slip straps, fully lined bottom for secure fit and maximum coverage, and the recommendation to machine wash and line dry for best results.
# Predicted Answer: Some key features of the Infant and Toddler Girls' Coastal Chill Swimsuit, Two-Piece are:
# - Bright colors, ruffles, and exclusive whimsical prints
# - Four-way-stretch and chlorine-resistant fabric
# - UPF 50+ rated fabric for high sun protection
# - Crossover no-slip straps and fully lined bottom for a secure fit and coverage
# - Machine washable and best results with line drying
#
# Example 5:
# Question: What is the composition of the body and lining of the Refresh Swimwear, V-Neck Tankini Contrasts?
# Real Answer: The body of the tankini is made of 82% recycled nylon and 18% Lycra® spandex, while the lining is made of 90% recycled nylon and 10% Lycra® spandex.
# Predicted Answer: The body of the Refresh Swimwear, V-Neck Tankini Contrasts is made of 82% recycled nylon with 18% Lycra® spandex, while the lining is made of 90% recycled nylon with 10% Lycra® spandex.
#
# Example 6:
# Question: What technology is used in the EcoFlex 3L Storm Pants to make them more breathable?
# Real Answer: The EcoFlex 3L Storm Pants utilize the state-of-the-art TEK O2 technology to offer the most breathability.
# Predicted Answer: The EcoFlex 3L Storm Pants use TEK O2 technology to make them more breathable.
#
# Example 7:
# Question: What is the approximate weight of the Women's Campside Oxfords per pair?
# Real Answer: The approximate weight of the Women's Campside Oxfords per pair is 1 lb. 1 oz.
# Predicted Answer: The approximate weight of the Women's Campside Oxfords per pair is 1 lb. 1 oz.
#
# Example 8:
# Question: What are the dimensions of the small and medium sizes of the Recycled Waterhog Dog Mat, Chevron Weave?
# Real Answer: The small size has dimensions of 18" x 28" and the medium size has dimensions of 22.5" x 34.5".
# Predicted Answer: The dimensions of the small size of the Recycled Waterhog Dog Mat, Chevron Weave are 18" x 28", and the dimensions of the medium size are 22.5" x 34.5".
#
# Example 9:
# Question: What are some key features of the Infant and Toddler Girls' Coastal Chill Swimsuit, Two-Piece according to the document?
# Real Answer: Some key features of the Infant and Toddler Girls' Coastal Chill Swimsuit, Two-Piece include bright colors, ruffles, exclusive whimsical prints, four-way-stretch and chlorine-resistant fabric, UPF 50+ rated fabric for sun protection, crossover no-slip straps, fully lined bottom for secure fit and maximum coverage, and the recommendation to machine wash and line dry for best results.
# Predicted Answer: Some key features of the Infant and Toddler Girls' Coastal Chill Swimsuit, Two-Piece are:
# - Bright colors, ruffles, and exclusive whimsical prints
# - Four-way-stretch and chlorine-resistant fabric
# - UPF 50+ rated fabric for high sun protection
# - Crossover no-slip straps and fully lined bottom for a secure fit and coverage
# - Machine washable and line dry for best results
#
# Example 10:
# Question: What is the composition of the body and lining of the Refresh Swimwear, V-Neck Tankini Contrasts?
# Real Answer: The body of the tankini is made of 82% recycled nylon and 18% Lycra® spandex, while the lining is made of 90% recycled nylon and 10% Lycra® spandex.
# Predicted Answer: The body of the Refresh Swimwear, V-Neck Tankini Contrasts is made of 82% recycled nylon with 18% Lycra® spandex, while the lining is made of 90% recycled nylon with 10% Lycra® spandex.
#
# Example 11:
# Question: What technology is used in the EcoFlex 3L Storm Pants to make them more breathable?
# Real Answer: The EcoFlex 3L Storm Pants utilize the state-of-the-art TEK O2 technology to offer the most breathability.
# Predicted Answer: The EcoFlex 3L Storm Pants use TEK O2 technology to make them more breathable.

# %% [markdown]
# ### Example 2
# One can also easily evaluate your QA chains with the metrics offered in ragas

# %%
from langchain_huggingface import HuggingFaceEmbeddings
loader = TextLoader("./data/nyc_text.txt")
index = VectorstoreIndexCreator(embedding=HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2", model_kwargs = {'device': 'mps'})).from_loaders([loader])


llm = ChatOpenAI(temperature= 0)
qa_chain = RetrievalQA.from_chain_type(
    llm,
    retriever=index.vectorstore.as_retriever(),
    return_source_documents=True,
)
# Out:
# /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages/langchain/indexes/vectorstore.py:127: UserWarning: Using InMemoryVectorStore as the default vectorstore.This memory store won't persist data. You should explicitlyspecify a vectorstore when using VectorstoreIndexCreator
#   warnings.warn(

# %%
# testing it out

question = "How did New York City get its name?"
result = qa_chain.invoke({"query": question})
result["result"]
# Out:
# 'New York City was originally named New Amsterdam by Dutch colonists in 1626. It was later renamed New York when the city came under British control in 1664, after King Charles II of England granted the lands to his brother, the Duke of York. The city was briefly renamed New Orange when the Dutch regained control in 1673, but it has been continuously named New York since November 1674.'

# %%
result
# Out:
# {'query': 'How did New York City get its name?',
#  'result': 'New York City was originally named New Amsterdam by Dutch colonists in 1626. It was later renamed New York when the city came under British control in 1664, after King Charles II of England granted the lands to his brother, the Duke of York. The city was briefly renamed New Orange when the Dutch regained control in 1673, but it has been continuously named New York since November 1674.',
#  'source_documents': [Document(id='cbe89331-8e5c-4338-b7c9-a1f5af286f91', metadata={'source': './data/nyc_text.txt'}, page_content='The city and its metropolitan area constitute the premier gateway for legal immigration to the United States. As many as 800 languages are spoken in New York, making it the most linguistically diverse city in the world. New York City is home to more than 3.2 million residents born outside the U.S., the largest foreign-born population of any city in the world as of 2016.New York City traces its origins to a trading post founded on the southern tip of Manhattan Island by Dutch colonists in approximately 1624. The settlement was named New Amsterdam (Dutch: Nieuw Amsterdam) in 1626 and was chartered as a city in 1653. The city came under British control in 1664 and was renamed New York after King Charles II of England granted the lands to his brother, the Duke of York. The city was regained by the Dutch in July 1673 and was renamed New Orange for one year and three months; the city has been continuously named New York since November 1674. New York City was the capital of the United States'),
#   Document(id='2e1d8913-2d19-4650-9161-4ee20560ab52', metadata={'source': './data/nyc_text.txt'}, page_content='New York City has been a metropolitan municipality with a Strong mayor–council form of government since its consolidation in 1898. In New York City, the city government is responsible for public education, correctional institutions, public safety, recreational facilities, sanitation, water supply, and welfare services.'),
#   Document(id='591ac6b9-4e74-4ad1-9780-94eee4ec37b7', metadata={'source': './data/nyc_text.txt'}, page_content="Despite New York's heavy reliance on its vast public transit system, streets are a defining feature of the city. The Commissioners' Plan of 1811 greatly influenced the city's physical development. Several of the city's streets and avenues, including Broadway, Wall Street, Madison Avenue, and Seventh Avenue are also used as metonyms for national industries there: the theater, finance, advertising, and fashion organizations, respectively."),
#   Document(id='66952f31-f87c-4d3e-a9a5-4dbf66205819', metadata={'source': './data/nyc_text.txt'}, page_content="In the pre-Columbian era, the area of present-day New York City was inhabited by Algonquian Native Americans, including the Lenape. Their homeland, known as Lenapehoking, included the present-day areas of Staten Island, Manhattan, the Bronx, the western portion of Long Island (including the areas that would later become the boroughs of Brooklyn and Queens), and the Lower Hudson Valley.The first documented visit into New York Harbor by a European was in 1524 by Italian Giovanni da Verrazzano, an explorer from Florence in the service of the French crown. He claimed the area for France and named it Nouvelle Angoulême (New Angoulême). A Spanish expedition, led by the Portuguese captain Estêvão Gomes sailing for Emperor Charles V, arrived in New York Harbor in January 1525 and charted the mouth of the Hudson River, which he named Río de San Antonio ('Saint Anthony's River'). The Padrón Real of 1527, the first scientific map to show the East Coast of North America continuously, was informed")]}

# %% [markdown]
# Now in order to evaluate the qa system we generated a few relevant questions. We've generated a few question for you but feel free to add any you want.

# %%
eval_questions = [
    "What is the population of New York City as of 2020?",
    "Which borough of New York City has the highest population?",
    "What is the economic significance of New York City?",
    "How did New York City get its name?",
    "What is the significance of the Statue of Liberty in New York City?",
]

eval_answers = [
    "8,804,190",
    "Brooklyn",
    "New York City's economic significance is vast, as it serves as the global financial capital, housing Wall Street and major financial institutions. Its diverse economy spans technology, media, healthcare, education, and more, making it resilient to economic fluctuations. NYC is a hub for international business, attracting global companies, and boasts a large, skilled labor force. Its real estate market, tourism, cultural industries, and educational institutions further fuel its economic prowess. The city's transportation network and global influence amplify its impact on the world stage, solidifying its status as a vital economic player and cultural epicenter.",
    "New York City got its name when it came under British control in 1664. King Charles II of England granted the lands to his brother, the Duke of York, who named the city New York in his own honor.",
    "The Statue of Liberty in New York City holds great significance as a symbol of the United States and its ideals of liberty and peace. It greeted millions of immigrants who arrived in the U.S. by ship in the late 19th and early 20th centuries, representing hope and freedom for those seeking a better life. It has since become an iconic landmark and a global symbol of cultural diversity and freedom.",
]

examples = [
    {"query": q, "ground_truths": [eval_answers[i]]}
    for i, q in enumerate(eval_questions)
]

# %%
examples
# Out:
# [{'query': 'What is the population of New York City as of 2020?',
#   'ground_truths': ['8,804,190']},
#  {'query': 'Which borough of New York City has the highest population?',
#   'ground_truths': ['Brooklyn']},
#  {'query': 'What is the economic significance of New York City?',
#   'ground_truths': ["New York City's economic significance is vast, as it serves as the global financial capital, housing Wall Street and major financial institutions. Its diverse economy spans technology, media, healthcare, education, and more, making it resilient to economic fluctuations. NYC is a hub for international business, attracting global companies, and boasts a large, skilled labor force. Its real estate market, tourism, cultural industries, and educational institutions further fuel its economic prowess. The city's transportation network and global influence amplify its impact on the world stage, solidifying its status as a vital economic player and cultural epicenter."]},
#  {'query': 'How did New York City get its name?',
#   'ground_truths': ['New York City got its name when it came under British control in 1664. King Charles II of England granted the lands to his brother, the Duke of York, who named the city New York in his own honor.']},
#  {'query': 'What is the significance of the Statue of Liberty in New York City?',
#   'ground_truths': ['The Statue of Liberty in New York City holds great significance as a symbol of the United States and its ideals of liberty and peace. It greeted millions of immigrants who arrived in the U.S. by ship in the late 19th and early 20th centuries, representing hope and freedom for those seeking a better life. It has since become an iconic landmark and a global symbol of cultural diversity and freedom.']}]

# %% [markdown]
# #### Introducing RagasEvaluatorChain

# %% [markdown]
# `RagasEvaluatorChain` creates a wrapper around the metrics ragas provides (documented [here](https://github.com/explodinggradients/ragas/blob/main/docs/metrics.md)), making it easier to run these evaluation with langchain and langsmith.
#
# The evaluator chain has the following APIs
#
# - `__call__()`: call the `RagasEvaluatorChain` directly on the result of a QA chain.
# - `evaluate()`: evaluate on a list of examples (with the input queries) and predictions (outputs from the QA chain).
# - `evaluate_run()`: method implemented that is called by langsmith evaluators to evaluate langsmith datasets.
#
# lets see each of them in action to learn more.

# %%
result = qa_chain.invoke({"query": eval_questions[1]})
result["result"]
# Out:
# 'Manhattan (New York County) has the highest population density of any borough in New York City.'

# %%
key_mapping = {
    "query": "question",
    "result": "answer",
    "source_documents": "contexts"
}

result_updated = {}
for old_key, new_key in key_mapping.items():
    if old_key in result:
        result_updated[new_key] = result[old_key]

# %%
result_updated
# Out:
# {'question': 'Which borough of New York City has the highest population?',
#  'answer': 'Manhattan (New York County) has the highest population density of any borough in New York City.',
#  'contexts': [Document(id='fdfc7c02-6245-4e1f-810a-e918f9967692', metadata={'source': './data/nyc_text.txt'}, page_content="New York City is the most populous city in the United States, with 8,804,190 residents incorporating more immigration into the city than outmigration since the 2010 United States census. More than twice as many people live in New York City as compared to Los Angeles, the second-most populous U.S. city; and New York has more than three times the population of Chicago, the third-most populous U.S. city. New York City gained more residents between 2010 and 2020 (629,000) than any other U.S. city, and a greater amount than the total sum of the gains over the same decade of the next four largest U.S. cities, Los Angeles, Chicago, Houston, and Phoenix, Arizona combined. New York City's population is about 44% of New York State's population, and about 39% of the population of the New York metropolitan area. The majority of New York City residents in 2020 (5,141,538, or 58.4%) were living on Long Island, in Brooklyn, or in Queens. The New York City metropolitan statistical area, has the"),
#   Document(id='05178946-4f56-4720-bfc2-b84be386b5cf', metadata={'source': './data/nyc_text.txt'}, page_content="New York, often called New York City or NYC, is the most populous city in the United States. With a 2020 population of 8,804,190 distributed over 300.46 square miles (778.2 km2), New York City is the most densely populated major city in the United States and more than twice as populous as Los Angeles, the nation's second-largest city. New York City is located at the southern tip of New York State. It constitutes the geographical and demographic center of both the Northeast megalopolis and the New York metropolitan area, the largest metropolitan area in the U.S. by both population and urban area. With over 20.1 million people in its metropolitan statistical area and 23.5 million in its combined statistical area as of 2020, New York is one of the world's most populous megacities, and over 58 million people live within 250 mi (400 km) of the city. New York City is a global cultural, financial, entertainment, and media center with a significant influence on commerce, health care and life"),
#   Document(id='2f795262-05d9-4b71-99f6-d6be51553f11', metadata={'source': './data/nyc_text.txt'}, page_content="Manhattan (New York County) is the geographically smallest and most densely populated borough. It is home to Central Park and most of the city's skyscrapers, and is sometimes locally known as The City. Manhattan's population density of 72,033 people per square mile (27,812/km2) in 2015 makes it the highest of any county in the United States and higher than the density of any individual American city.Manhattan is the cultural, administrative, and financial center of New York City and contains the headquarters of many major multinational corporations, the United Nations headquarters, Wall Street, and a number of important universities. The borough of Manhattan is often described as the financial and cultural center of the world.Most of the borough is situated on Manhattan Island, at the mouth of the Hudson River and the East River, and its southern tip, at the confluence of the two rivers, represents the birthplace of New York City itself. Several small islands also compose part of the"),
#   Document(id='2ac0bf1d-6bb6-420f-936f-fd4efaf806ee', metadata={'source': './data/nyc_text.txt'}, page_content="=== Population density ===\n\nIn 2020, the city had an estimated population density of 29,302.37 inhabitants per square mile (11,313.71/km2), rendering it the nation's most densely populated of all larger municipalities (those with more than 100,000 residents), with several small cities (of fewer than 100,000) in adjacent Hudson County, New Jersey having greater density, as per the 2010 census. Geographically co-extensive with New York County, the borough of Manhattan's 2017 population density of 72,918 inhabitants per square mile (28,154/km2) makes it the highest of any county in the United States and higher than the density of any individual American city. The next three densest counties in the United States, placing second through fourth, are also New York boroughs: Brooklyn, the Bronx, and Queens respectively.\n\n\n=== Race and ethnicity ===")]}

# %%
 # !pip install --no-cache-dir recordclass
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting recordclass
#   Downloading recordclass-0.24.tar.gz (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 1.4 MB/s  0:00:01 eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: recordclass
#   Building wheel for recordclass (pyproject.toml) ... done
#   Created wheel for recordclass: filename=recordclass-0.24-cp311-cp311-macosx_12_0_arm64.whl size=244908 sha256=a7d112ebee06c03489b0cad736a092bbd198c65dbe6ee4c175160a4fcb991209
#   Stored in directory: /private/var/folders/3k/my8rx_2936x18t9wy2ywg_lm0000gn/T/pip-ephem-wheel-cache-seo1kqnd/wheels/43/69/ac/4af8fb73bb1a9ebd40a440afd8fc8f648c01d3f83a63b51d4c
# Successfully built recordclass
# Installing collected packages: recordclass
# Successfully installed recordclass-0.24

# %%
 # !pip install ragas==0.1.9
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting ragas==0.1.9
#   Downloading ragas-0.1.9-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from ragas==0.1.9) (1.26.4)
# Requirement already satisfied: datasets in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from ragas==0.1.9) (5.0.0)
# Requirement already satisfied: tiktoken in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from ragas==0.1.9) (0.13.0)
# Requirement already satisfied: langchain in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from ragas==0.1.9) (0.2.17)
# Requirement already satisfied: langchain-core in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from ragas==0.1.9) (0.2.43)
# Requirement already satisfied: langchain-community in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from ragas==0.1.9) (0.2.19)
# Requirement already satisfied: langchain-openai in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from ragas==0.1.9) (0.1.25)
# Requirement already satisfied: openai>1 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from ragas==0.1.9) (1.109.1)
# Collecting pysbd>=0.3.4 (from ragas==0.1.9)
#   Downloading pysbd-0.3.4-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from ragas==0.1.9) (1.6.0)
# Collecting appdirs (from ragas==0.1.9)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from openai>1->ragas==0.1.9) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from openai>1->ragas==0.1.9) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from openai>1->ragas==0.1.9) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from openai>1->ragas==0.1.9) (0.15.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from openai>1->ragas==0.1.9) (2.13.4)
# Requirement already satisfied: sniffio in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from openai>1->ragas==0.1.9) (1.3.1)
# Requirement already satisfied: tqdm>4 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from openai>1->ragas==0.1.9) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from openai>1->ragas==0.1.9) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai>1->ragas==0.1.9) (3.15)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai>1->ragas==0.1.9) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai>1->ragas==0.1.9) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>1->ragas==0.1.9) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai>1->ragas==0.1.9) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai>1->ragas==0.1.9) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai>1->ragas==0.1.9) (0.4.2)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from datasets->ragas==0.1.9) (3.29.0)
# Requirement already satisfied: pyarrow>=21.0.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from datasets->ragas==0.1.9) (24.0.0)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from datasets->ragas==0.1.9) (0.4.1)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from datasets->ragas==0.1.9) (3.0.3)
# Requirement already satisfied: requests>=2.32.2 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from datasets->ragas==0.1.9) (2.34.2)
# Requirement already satisfied: xxhash in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from datasets->ragas==0.1.9) (3.7.0)
# Requirement already satisfied: multiprocess<0.70.20 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from datasets->ragas==0.1.9) (0.70.19)
# Requirement already satisfied: fsspec<=2026.4.0,>=2023.1.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from fsspec[http]<=2026.4.0,>=2023.1.0->datasets->ragas==0.1.9) (2026.2.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from datasets->ragas==0.1.9) (0.36.2)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from datasets->ragas==0.1.9) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from datasets->ragas==0.1.9) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from fsspec[http]<=2026.4.0,>=2023.1.0->datasets->ragas==0.1.9) (3.13.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets->ragas==0.1.9) (1.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets->ragas==0.1.9) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets->ragas==0.1.9) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets->ragas==0.1.9) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets->ragas==0.1.9) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets->ragas==0.1.9) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets->ragas==0.1.9) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets->ragas==0.1.9) (1.24.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from requests>=2.32.2->datasets->ragas==0.1.9) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from requests>=2.32.2->datasets->ragas==0.1.9) (2.7.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from langchain->ragas==0.1.9) (2.0.49)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from langchain->ragas==0.1.9) (0.2.4)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from langchain->ragas==0.1.9) (0.1.147)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from langchain->ragas==0.1.9) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from langchain-core->ragas==0.1.9) (1.33)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core->ragas==0.1.9) (3.1.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.17->langchain->ragas==0.1.9) (3.11.9)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.17->langchain->ragas==0.1.9) (1.0.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from langchain-community->ragas==0.1.9) (0.6.7)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community->ragas==0.1.9) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community->ragas==0.1.9) (0.9.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community->ragas==0.1.9) (1.1.0)
# Requirement already satisfied: regex in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from tiktoken->ragas==0.1.9) (2026.5.9)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from pandas->datasets->ragas==0.1.9) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets->ragas==0.1.9) (1.17.0)
# Downloading ragas-0.1.9-py3-none-any.whl (86 kB)
# Downloading pysbd-0.3.4-py3-none-any.whl (71 kB)
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Installing collected packages: appdirs, pysbd, ragas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [ragas]
# Successfully installed appdirs-1.4.4 pysbd-0.3.4 ragas-0.1.9

# %%
from ragas.integrations.langchain import EvaluatorChain 
# from ragas import evaluate
from ragas.metrics import (
    faithfulness,
    answer_relevancy,
    context_relevancy,
    context_recall,
)

# create evaluation chains
faithfulness_chain   = EvaluatorChain(metric=faithfulness)
answer_rel_chain     = EvaluatorChain(metric=answer_relevancy)
context_rel_chain    = EvaluatorChain(metric=context_relevancy)
context_recall_chain = EvaluatorChain(metric=context_recall)

# %% [markdown]
# 1. `__call__()`
#
# Directly run the evaluation chain with the results from the QA chain. Do note that metrics like context_relevancy and faithfulness require the `source_documents` to be present.

# %%
# Recheck the result that we are going to validate.
result
# Out:
# {'query': 'Which borough of New York City has the highest population?',
#  'result': 'Manhattan (New York County) has the highest population density of any borough in New York City.',
#  'source_documents': [Document(id='fdfc7c02-6245-4e1f-810a-e918f9967692', metadata={'source': './data/nyc_text.txt'}, page_content="New York City is the most populous city in the United States, with 8,804,190 residents incorporating more immigration into the city than outmigration since the 2010 United States census. More than twice as many people live in New York City as compared to Los Angeles, the second-most populous U.S. city; and New York has more than three times the population of Chicago, the third-most populous U.S. city. New York City gained more residents between 2010 and 2020 (629,000) than any other U.S. city, and a greater amount than the total sum of the gains over the same decade of the next four largest U.S. cities, Los Angeles, Chicago, Houston, and Phoenix, Arizona combined. New York City's population is about 44% of New York State's population, and about 39% of the population of the New York metropolitan area. The majority of New York City residents in 2020 (5,141,538, or 58.4%) were living on Long Island, in Brooklyn, or in Queens. The New York City metropolitan statistical area, has the"),
#   Document(id='05178946-4f56-4720-bfc2-b84be386b5cf', metadata={'source': './data/nyc_text.txt'}, page_content="New York, often called New York City or NYC, is the most populous city in the United States. With a 2020 population of 8,804,190 distributed over 300.46 square miles (778.2 km2), New York City is the most densely populated major city in the United States and more than twice as populous as Los Angeles, the nation's second-largest city. New York City is located at the southern tip of New York State. It constitutes the geographical and demographic center of both the Northeast megalopolis and the New York metropolitan area, the largest metropolitan area in the U.S. by both population and urban area. With over 20.1 million people in its metropolitan statistical area and 23.5 million in its combined statistical area as of 2020, New York is one of the world's most populous megacities, and over 58 million people live within 250 mi (400 km) of the city. New York City is a global cultural, financial, entertainment, and media center with a significant influence on commerce, health care and life"),
#   Document(id='2f795262-05d9-4b71-99f6-d6be51553f11', metadata={'source': './data/nyc_text.txt'}, page_content="Manhattan (New York County) is the geographically smallest and most densely populated borough. It is home to Central Park and most of the city's skyscrapers, and is sometimes locally known as The City. Manhattan's population density of 72,033 people per square mile (27,812/km2) in 2015 makes it the highest of any county in the United States and higher than the density of any individual American city.Manhattan is the cultural, administrative, and financial center of New York City and contains the headquarters of many major multinational corporations, the United Nations headquarters, Wall Street, and a number of important universities. The borough of Manhattan is often described as the financial and cultural center of the world.Most of the borough is situated on Manhattan Island, at the mouth of the Hudson River and the East River, and its southern tip, at the confluence of the two rivers, represents the birthplace of New York City itself. Several small islands also compose part of the"),
#   Document(id='2ac0bf1d-6bb6-420f-936f-fd4efaf806ee', metadata={'source': './data/nyc_text.txt'}, page_content="=== Population density ===\n\nIn 2020, the city had an estimated population density of 29,302.37 inhabitants per square mile (11,313.71/km2), rendering it the nation's most densely populated of all larger municipalities (those with more than 100,000 residents), with several small cities (of fewer than 100,000) in adjacent Hudson County, New Jersey having greater density, as per the 2010 census. Geographically co-extensive with New York County, the borough of Manhattan's 2017 population density of 72,918 inhabitants per square mile (28,154/km2) makes it the highest of any county in the United States and higher than the density of any individual American city. The next three densest counties in the United States, placing second through fourth, are also New York boroughs: Brooklyn, the Bronx, and Queens respectively.\n\n\n=== Race and ethnicity ===")]}

# %% [markdown]
# **Faithfulness**

# %%
eval_result = faithfulness_chain(result_updated)
eval_result["faithfulness_score"]
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 eval_result = faithfulness_chain(result_updated)
#       2 eval_result["faithfulness_score"]
#
# File /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:180, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     178     warned = True
#     179     emit_warning()
# --> 180 return wrapped(*args, **kwargs)
#
# File /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages/langchain/chains/base.py:380, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     348 """Execute the chain.
#     349
#     350 Args:
#    (...)    371         `Chain.output_keys`.
#     372 """
#     373 config = {
#     374     "callbacks": callbacks,
#     375     "tags": tags,
#     376     "metadata": metadata,
#     377     "run_name": run_name,
#     378 }
# --> 380 return self.invoke(
#     381     inputs,
#     382     cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#     383     return_only_outputs=return_only_outputs,
#     384     include_run_info=include_run_info,
#     385 )
#
# File /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages/langchain/chains/base.py:163, in Chain.invoke(self, input, config, **kwargs)
#     161 except BaseException as e:
#     162     run_manager.on_chain_error(e)
# --> 163     raise e
#     164 run_manager.on_chain_end(outputs)
#     166 if include_run_info:
#
# File /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages/langchain/chains/base.py:153, in Chain.invoke(self, input, config, **kwargs)
#     150 try:
#     151     self._validate_inputs(inputs)
#     152     outputs = (
# --> 153         self._call(inputs, run_manager=run_manager)
#     154         if new_arg_supported
#     155         else self._call(inputs)
#     156     )
#     158     final_outputs: Dict[str, Any] = self.prep_outputs(
#     159         inputs, outputs, return_only_outputs
#     160     )
#     161 except BaseException as e:
#
# File /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages/ragas/integrations/langchain.py:79, in EvaluatorChain._call(self, inputs, run_manager)
#      77 q = inputs.get("question", "")
#      78 a = inputs.get("answer", "")
# ---> 79 score = self.metric.score(
#      80     {
#      81         "question": q,
#      82         "answer": a,
#      83         "contexts": c,
#      84         "ground_truth": g,
#      85     },
#      86     callbacks=callbacks,
#      87 )
#      88 return {self.metric.name: score}
#
# File /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages/ragas/metrics/base.py:107, in Metric.score(self, row, callbacks)
#     105     if not group_cm.ended:
#     106         rm.on_chain_error(e)
# --> 107     raise e
#     108 else:
#     109     if not group_cm.ended:
#
# File /opt/anaconda3/envs/qa-lab/lib/python3.11/site-packages/ragas/metrics/base.py:101, in Metric.score(self, row, callbacks)
#      97 rm, group_cm = new_group(
#      98     self.name, inputs=row, callbacks=callbacks, is_async=False
#      99 )
#     100 try:
# --> 101     score = asyncio.run(
#     102         self._ascore(row=row, callbacks=group_cm, is_async=False)
#     103     )
#     104 except Exception as e:
#     105     if not group_cm.ended:
#
# File /opt/anaconda3/envs/qa-lab/lib/python3.11/asyncio/runners.py:186, in run(main, debug)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)    182     asyncio.run(main())
#     183 """
#     184 if events._get_running_loop() is not None:
#     185     # fail fast with short traceback
# --> 186     raise RuntimeError(
#     187         "asyncio.run() cannot be called from a running event loop")
#     189 with Runner(debug=debug) as runner:
#     190     return runner.run(main)
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %% [markdown]
# High faithfulness_score means that there are exact consistency between the source documents and the answer.
#
# You can check lower faithfulness scores by changing the result (answer from LLM) or source_documents to something else.

# %%
fake_result = result.copy()
fake_result["result"] = "we are the champions"
eval_result = faithfulness_chain(fake_result)
eval_result["faithfulness_score"]

# %% [markdown]
# **Context Relevancy**

# %%
eval_result = context_recall_chain(result)
eval_result["context_recall_score"]

# %% [markdown]
# High context_recall_score means that the ground truth is present in the source documents.
#
# You can check lower context recall scores by changing the source_documents to something else.

# %%
from langchain.schema import Document
fake_result = result.copy()
fake_result["source_documents"] = [Document(page_content="I love christmas")]
eval_result = context_recall_chain(fake_result)
eval_result["context_recall_score"]

# %% [markdown]
# 2. `evaluate()`
#
# Evaluate a list of inputs/queries and the outputs/predictions from the QA chain.

# %%
# run the queries as a batch for efficiency
predictions = qa_chain.batch(examples)

# evaluate
print("evaluating...")
r = faithfulness_chain.evaluate(examples, predictions)
r

# %%
# evaluate context recall
print("evaluating...")
r = context_recall_chain.evaluate(examples, predictions)
r
